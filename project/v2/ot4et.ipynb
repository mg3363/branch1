# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по практической работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Информационные технологии и программирование»</b></center>
# <center>на тему</center>
# <center><b>"GIT"</b> </center>
# </font>
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2302 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Грошева Марина Сергеевна</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Фёдоров Владимир Дмитриевич  </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# > ## Содержание

# %% [markdown]
# <a href = '#Постановка_задач'>1. Постановка задач </a>
#
# <a href = '#Задачи работы'>2. Задачи работы </a>
#
# <a href = '#Ход работы'>3. Ход работы </a>
#
# <a href = '#Результат выполнения работы'>4. Результат выполнения работы </a>

# %% [markdown]
# # Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# Задача: разместить на github ранее созданный статический сайт

# %% [markdown]
# Цель работы: разместить на github ранее созданный статический и динамический сайт

# %% [markdown]
# #Задачи работы
# <a name = 'Задачи работы'>

# %% [markdown]
# 1. Установить GIT.
#
# 2. Создать локальный репозиторий.
#
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
#
# 4. Зафиксировать в отчете все проделанные шаги и создать версию отчета в GIT
#
# 5. Создать ветку отчета в GIT, добавить описания шагов в отчет и создать версию отчета в новой ветке
#
# 6. Слить последнее изменение отчета в основную ветку
#
# 7. Зарегистрироваться на github, создать проект «homework IIT», залить содержимое из локального репозитория в проект на githab
#
# 8. Разместить на github ранее созданный статический сайт
#
# *Разметить на github ранее созданный динамический сайт.
#
# 9. Завершить отчет, добавив описание всех пунктов

# %% [markdown]
# # Ход работы
# <a name = 'Ход работы'>

# %% [markdown]
# 1. Я установила Git Bash и выбрала папку с файлом отчета
#
# ![image.png](data:image/png;base64,...)
# ![telegram-cloud-photo-size-2-5474639820182639710-x.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. Создала локальный репозиторий
#
# ![telegram-cloud-photo-size-2-5474639820182639711-x.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. Создала файл отчета по выполнению практической работы и поместила его в репозиторий
# ![telegram-cloud-photo-size-2-5474639820182639731-x.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 5. Зафиксировала в отчете все проделанные шаги и создала версию отчета в GIT

# %% [markdown]
# 6. Слила последнее изменение отчета в основную ветку

# %% [markdown]
# 7. Зарегистрировалась на github, создала проект «homework IIT», залила содержимое из локального репозитория в проект на githab

# %% [markdown]
# 8. Разместила на github ранее созданный статический и динамический сайт

# %% [markdown]
# 9. Завершила отчет, добавив описание всех пунктов

# %% [markdown]
# # Результат выполнения работы
# <a name = 'Результат выполнения работы'>

# %% [markdown]
# **В результате выполнения работы, я научилась создавать локальный репозиторий и размещать ранее созданный сайт на github**
